# %% [markdown]
# <h3>Importando Bibliotecas Python</h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_games = pd.read_csv('../data_raw/steam_games.csv')
df_games = df_games.reset_index(drop=False)

# %%
df_reviews = pd.read_csv('../data_raw/steam_reviews.csv')

# %%
df_games
# Out:
#          index                   AppID          Name Release date  \
# 0        20200        Galactic Bowling  Oct 21, 2008    0 - 20000
# 1       655370            Train Bandit  Oct 12, 2017    0 - 20000
# 2      1732930            Jolt Project  Nov 17, 2021    0 - 20000
# 3      1355720                Henosis™  Jul 23, 2020    0 - 20000
# 4      1139950   Two Weeks in Painland   Feb 3, 2020    0 - 20000
# ...        ...                     ...           ...          ...
# 97405  3080940  Femdom Game World: Mom  Aug 22, 2024    0 - 20000
# 97406  2593970             Blocky Farm  Aug 30, 2024        0 - 0
# 97407  3137150    Infiltrate & Extract  Aug 30, 2024        0 - 0
# 97408  3124670       Escape The Garage  Aug 29, 2024        0 - 0
# 97409  3054200              Lober Lobe  Aug 30, 2024        0 - 0
#
#        Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# 0                     0         0         19.99      0                  0
# ...
